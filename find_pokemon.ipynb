# %%
import requests
import os

def download_pokemon_image(pokedex_number, pokemon_name, save_path):
    # Forming the URL
    url = f"https://archives.bulbagarden.net/wiki/File:{pokedex_number:04d}{pokemon_name}.png#file"

    # Sending GET request to download the image
    response = requests.get(url)
    
    # If request was successful, save the image
    if response.status_code == 200:
        with open(os.path.join(save_path, f"{pokemon_name}.png"), "wb") as file:
            file.write(response.content)
        print(f"Image for {pokemon_name} downloaded successfully!")
    else:
        print(f"Error downloading image for {pokemon_name}.")

# Example usage
download_pokemon_image(1, "Bulbasaur", "img")
# Out:
# Image for Bulbasaur downloaded successfully!

# %%
import requests
from bs4 import BeautifulSoup

def download_pokemon_image(pokedex_number, pokemon_name, save_path):
    # Forming the URL
    url = f"https://archives.bulbagarden.net/wiki/File:{pokedex_number:04d}{pokemon_name}.png"
    
    # Sending GET request to the URL
    response = requests.get(url)
    
    if response.status_code == 200:
        # Parse the webpage content with BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the actual image URL (you might need to adjust this based on the webpage structure)
        img_url = soup.find('a', {'href': '#file'}).find_next('a')['href']
        print(f"Image Url: {img_url}")
        
        # Download the image from the actual URL
        img_response = requests.get(img_url)
        
        if img_response.status_code == 200:
            # Ensure the directory exists; create it if not.
            os.makedirs(save_path, exist_ok=True)
            with open(os.path.join(save_path, f"{pokemon_name}.png"), "wb") as file:
                file.write(img_response.content)
            print(f"Image for {pokemon_name} downloaded successfully!")
        else:
            print(f"Error downloading image for {pokemon_name}.")
    else:
        print(f"Error accessing page for {pokemon_name}.")

# Example usage
download_pokemon_image(1, "Bulbasaur", "img")
# Out:
# Image Url: #filehistory
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# c:\Users\ytsop\OneDrive\Desktop\Code\pokemath\find_pokemon.ipynb Cell 3 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=30'>31</a>         print(f"Error accessing page for {pokemon_name}.")
#      <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=32'>33</a> # Example usage
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=33'>34</a> download_pokemon_image(1, "Bulbasaur", "img")
#
# c:\Users\ytsop\OneDrive\Desktop\Code\pokemath\find_pokemon.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> print(f"Image Url: {img_url}")
#      <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> # Download the image from the actual URL
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a> img_response = requests.get(img_url)
#      <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a> if img_response.status_code == 200:
#      <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a>     # Ensure the directory exists; create it if not.
#      <a href='vscode-notebook-cell:/c%3A/Users/ytsop/OneDrive/Desktop/Code/pokemath/find_pokemon.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a>     os.makedirs(save_path, exist_ok=True)
#
# File c:\Users\ytsop\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\ytsop\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\ytsop\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:575, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     562 # Create the Request.
#     563 req = Request(
#     564     method=method.upper(),
#     565     url=url,
#    (...)
#     573     hooks=hooks,
#     574 )
# --> 575 prep = self.prepare_request(req)
#     577 proxies = proxies or {}
#     579 settings = self.merge_environment_settings(
#     580     prep.url, proxies, stream, verify, cert
#     581 )
#
# File c:\Users\ytsop\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:486, in Session.prepare_request(self, request)
#     483     auth = get_netrc_auth(request.url)
#     485 p = PreparedRequest()
# --> 486 p.prepare(
#     487     method=request.method.upper(),
#     488     url=request.url,
#     489     files=request.files,
#     490     data=request.data,
#     491     json=request.json,
#     492     headers=merge_setting(
#     493         request.headers, self.headers, dict_class=CaseInsensitiveDict
#     494     ),
#     495     params=merge_setting(request.params, self.params),
#     496     auth=merge_setting(auth, self.auth),
#     497     cookies=merged_cookies,
#     498     hooks=merge_hooks(request.hooks, self.hooks),
#     499 )
#     500 return p
#
# File c:\Users\ytsop\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:368, in PreparedRequest.prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     365 """Prepares the entire request with the given parameters."""
#     367 self.prepare_method(method)
# --> 368 self.prepare_url(url, params)
#     369 self.prepare_headers(headers)
#     370 self.prepare_cookies(cookies)
#
# File c:\Users\ytsop\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\models.py:439, in PreparedRequest.prepare_url(self, url, params)
#     436     raise InvalidURL(*e.args)
#     438 if not scheme:
# --> 439     raise MissingSchema(
#     440         f"Invalid URL {url!r}: No scheme supplied. "
#     441         f"Perhaps you meant https://{url}?"
#     442     )
#     444 if not host:
#     445     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
#
# MissingSchema: Invalid URL '#filehistory': No scheme supplied. Perhaps you meant https://#filehistory?

# %%
from bs4 import BeautifulSoup
import requests
import os

def get_pokemon_image_url(pokedex_number, pokemon_name):
    # Construct the URL of the Pokemon page on the archives.bulbagarden.net
    url = f"https://archives.bulbagarden.net/wiki/File:{pokedex_number:04d}{pokemon_name}.png"
    
    # Send a GET request to the URL
    response = requests.get(url)
    
    # If the GET request is successful, proceed
    if response.status_code == 200:
        # Parse the page content with Beautiful Soup
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the img tag with the specific alt attribute
        img_tag = soup.find('img', alt=f"File:{pokedex_number:04d}{pokemon_name}.png")
        
        # If the img tag is found, extract and return the src attribute (image URL)
        if img_tag:
            return img_tag['src']
    return None

# Example usage
url = get_pokemon_image_url(151, "Mew")
print(url)
# Out:
# https://archives.bulbagarden.net/media/upload/thumb/9/9a/0151Mew.png/600px-0151Mew.png

# %%
def download_pokemon_image(pokedex_number, pokemon_name, save_path):
    # Forming the URL
    url = get_pokemon_image_url(pokedex_number, pokemon_name)

    # Sending GET request to download the image
    response = requests.get(url)
    
    # If request was successful, save the image
    if response.status_code == 200:
        with open(os.path.join(save_path, f"{pokemon_name}.png"), "wb") as file:
            file.write(response.content)
        print(f"Image for {pokemon_name} downloaded successfully!")
    else:
        print(f"Error downloading image for {pokemon_name}.")

# %%
download_pokemon_image(151, "Mew", "img")
# Out:
# Image for Mew downloaded successfully!

# %%
import pypokedex

for dex in range(300, 1018):  # Range of pokemon that you wash to retrieve
    try:
        p = pypokedex.get(dex=dex)
        pokemon_name = p.name.capitalize()  # Capitalize the name for consistency with URLs
        download_pokemon_image(dex, pokemon_name, "img")
    except Exception as e:
        print(f"An error occurred while processing Pokémon number {dex}: {e}")
# Out:
# Image for Skitty downloaded successfully!
# Image for Delcatty downloaded successfully!
# Image for Sableye downloaded successfully!
# Image for Mawile downloaded successfully!
# Image for Aron downloaded successfully!
# Image for Lairon downloaded successfully!
# Image for Aggron downloaded successfully!
# Image for Meditite downloaded successfully!
# Image for Medicham downloaded successfully!
# Image for Electrike downloaded successfully!
# Image for Manectric downloaded successfully!
# Image for Plusle downloaded successfully!
# Image for Minun downloaded successfully!
# Image for Volbeat downloaded successfully!
# Image for Illumise downloaded successfully!
# Image for Roselia downloaded successfully!
# Image for Gulpin downloaded successfully!
# Image for Swalot downloaded successfully!
# Image for Carvanha downloaded successfully!
# Image for Sharpedo downloaded successfully!
# Image for Wailmer downloaded successfully!
# Image for Wailord downloaded successfully!
# Image for Numel downloaded successfully!
# Image for Camerupt downloaded successfully!
# Image for Torkoal downloaded successfully!
# Image for Spoink downloaded successfully!
# Image for Grumpig downloaded successfully!
# Image for Spinda downloaded successfully!
# Image for Trapinch downloaded successfully!
# Image for Vibrava downloaded successfully!
# Image for Flygon downloaded successfully!
# Image for Cacnea downloaded successfully!
# Image for Cacturne downloaded successfully!
# Image for Swablu downloaded successfully!
# Image for Altaria downloaded successfully!
# Image for Zangoose downloaded successfully!
# Image for Seviper downloaded successfully!
# Image for Lunatone downloaded successfully!
# Image for Solrock downloaded successfully!
# Image for Barboach downloaded successfully!
# Image for Whiscash downloaded successfully!
# Image for Corphish downloaded successfully!
# Image for Crawdaunt downloaded successfully!
# Image for Baltoy downloaded successfully!
# Image for Claydol downloaded successfully!
# Image for Lileep downloaded successfully!
# Image for Cradily downloaded successfully!
# Image for Anorith downloaded successfully!
# Image for Armaldo downloaded successfully!
# Image for Feebas downloaded successfully!
# Image for Milotic downloaded successfully!
# Image for Castform downloaded successfully!
# Image for Kecleon downloaded successfully!
# Image for Shuppet downloaded successfully!
# Image for Banette downloaded successfully!
# Image for Duskull downloaded successfully!
# Image for Dusclops downloaded successfully!
# Image for Tropius downloaded successfully!
# Image for Chimecho downloaded successfully!
# Image for Absol downloaded successfully!
# Image for Wynaut downloaded successfully!
# Image for Snorunt downloaded successfully!
# Image for Glalie downloaded successfully!
# Image for Spheal downloaded successfully!
# Image for Sealeo downloaded successfully!
# Image for Walrein downloaded successfully!
# Image for Clamperl downloaded successfully!
# Image for Huntail downloaded successfully!
# Image for Gorebyss downloaded successfully!
# Image for Relicanth downloaded successfully!
# Image for Luvdisc downloaded successfully!
# Image for Bagon downloaded successfully!
# Image for Shelgon downloaded successfully!
# Image for Salamence downloaded successfully!
# Image for Beldum downloaded successfully!
# Image for Metang downloaded successfully!
# Image for Metagross downloaded successfully!
# Image for Regirock downloaded successfully!
# Image for Regice downloaded successfully!
# Image for Registeel downloaded successfully!
# Image for Latias downloaded successfully!
# Image for Latios downloaded successfully!
# Image for Kyogre downloaded successfully!
# Image for Groudon downloaded successfully!
# Image for Rayquaza downloaded successfully!
# Image for Jirachi downloaded successfully!
# An error occurred while processing Pokémon number 386: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Turtwig downloaded successfully!
# Image for Grotle downloaded successfully!
# Image for Torterra downloaded successfully!
# Image for Chimchar downloaded successfully!
# Image for Monferno downloaded successfully!
# Image for Infernape downloaded successfully!
# Image for Piplup downloaded successfully!
# Image for Prinplup downloaded successfully!
# Image for Empoleon downloaded successfully!
# Image for Starly downloaded successfully!
# Image for Staravia downloaded successfully!
# Image for Staraptor downloaded successfully!
# Image for Bidoof downloaded successfully!
# Image for Bibarel downloaded successfully!
# Image for Kricketot downloaded successfully!
# Image for Kricketune downloaded successfully!
# Image for Shinx downloaded successfully!
# Image for Luxio downloaded successfully!
# Image for Luxray downloaded successfully!
# Image for Budew downloaded successfully!
# Image for Roserade downloaded successfully!
# Image for Cranidos downloaded successfully!
# Image for Rampardos downloaded successfully!
# Image for Shieldon downloaded successfully!
# Image for Bastiodon downloaded successfully!
# Image for Burmy downloaded successfully!
# An error occurred while processing Pokémon number 413: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Mothim downloaded successfully!
# Image for Combee downloaded successfully!
# Image for Vespiquen downloaded successfully!
# Image for Pachirisu downloaded successfully!
# Image for Buizel downloaded successfully!
# Image for Floatzel downloaded successfully!
# Image for Cherubi downloaded successfully!
# Image for Cherrim downloaded successfully!
# Image for Shellos downloaded successfully!
# Image for Gastrodon downloaded successfully!
# Image for Ambipom downloaded successfully!
# Image for Drifloon downloaded successfully!
# Image for Drifblim downloaded successfully!
# Image for Buneary downloaded successfully!
# Image for Lopunny downloaded successfully!
# Image for Mismagius downloaded successfully!
# Image for Honchkrow downloaded successfully!
# Image for Glameow downloaded successfully!
# Image for Purugly downloaded successfully!
# Image for Chingling downloaded successfully!
# Image for Stunky downloaded successfully!
# Image for Skuntank downloaded successfully!
# Image for Bronzor downloaded successfully!
# Image for Bronzong downloaded successfully!
# Image for Bonsly downloaded successfully!
# An error occurred while processing Pokémon number 439: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Happiny downloaded successfully!
# Image for Chatot downloaded successfully!
# Image for Spiritomb downloaded successfully!
# Image for Gible downloaded successfully!
# Image for Gabite downloaded successfully!
# Image for Garchomp downloaded successfully!
# Image for Munchlax downloaded successfully!
# Image for Riolu downloaded successfully!
# Image for Lucario downloaded successfully!
# Image for Hippopotas downloaded successfully!
# Image for Hippowdon downloaded successfully!
# Image for Skorupi downloaded successfully!
# Image for Drapion downloaded successfully!
# Image for Croagunk downloaded successfully!
# Image for Toxicroak downloaded successfully!
# Image for Carnivine downloaded successfully!
# Image for Finneon downloaded successfully!
# Image for Lumineon downloaded successfully!
# Image for Mantyke downloaded successfully!
# Image for Snover downloaded successfully!
# Image for Abomasnow downloaded successfully!
# Image for Weavile downloaded successfully!
# Image for Magnezone downloaded successfully!
# Image for Lickilicky downloaded successfully!
# Image for Rhyperior downloaded successfully!
# Image for Tangrowth downloaded successfully!
# Image for Electivire downloaded successfully!
# Image for Magmortar downloaded successfully!
# Image for Togekiss downloaded successfully!
# Image for Yanmega downloaded successfully!
# Image for Leafeon downloaded successfully!
# Image for Glaceon downloaded successfully!
# Image for Gliscor downloaded successfully!
# Image for Mamoswine downloaded successfully!
# An error occurred while processing Pokémon number 474: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Gallade downloaded successfully!
# Image for Probopass downloaded successfully!
# Image for Dusknoir downloaded successfully!
# Image for Froslass downloaded successfully!
# Image for Rotom downloaded successfully!
# Image for Uxie downloaded successfully!
# Image for Mesprit downloaded successfully!
# Image for Azelf downloaded successfully!
# Image for Dialga downloaded successfully!
# Image for Palkia downloaded successfully!
# Image for Heatran downloaded successfully!
# Image for Regigigas downloaded successfully!
# An error occurred while processing Pokémon number 487: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Cresselia downloaded successfully!
# Image for Phione downloaded successfully!
# Image for Manaphy downloaded successfully!
# Image for Darkrai downloaded successfully!
# An error occurred while processing Pokémon number 492: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Arceus downloaded successfully!
# Image for Victini downloaded successfully!
# Image for Snivy downloaded successfully!
# Image for Servine downloaded successfully!
# Image for Serperior downloaded successfully!
# Image for Tepig downloaded successfully!
# Image for Pignite downloaded successfully!
# Image for Emboar downloaded successfully!
# Image for Oshawott downloaded successfully!
# Image for Dewott downloaded successfully!
# Image for Samurott downloaded successfully!
# Image for Patrat downloaded successfully!
# Image for Watchog downloaded successfully!
# Image for Lillipup downloaded successfully!
# Image for Herdier downloaded successfully!
# Image for Stoutland downloaded successfully!
# Image for Purrloin downloaded successfully!
# Image for Liepard downloaded successfully!
# Image for Pansage downloaded successfully!
# Image for Simisage downloaded successfully!
# Image for Pansear downloaded successfully!
# Image for Simisear downloaded successfully!
# Image for Panpour downloaded successfully!
# Image for Simipour downloaded successfully!
# Image for Munna downloaded successfully!
# Image for Musharna downloaded successfully!
# Image for Pidove downloaded successfully!
# Image for Tranquill downloaded successfully!
# Image for Unfezant downloaded successfully!
# Image for Blitzle downloaded successfully!
# Image for Zebstrika downloaded successfully!
# Image for Roggenrola downloaded successfully!
# Image for Boldore downloaded successfully!
# Image for Gigalith downloaded successfully!
# Image for Woobat downloaded successfully!
# Image for Swoobat downloaded successfully!
# Image for Drilbur downloaded successfully!
# Image for Excadrill downloaded successfully!
# Image for Audino downloaded successfully!
# Image for Timburr downloaded successfully!
# Image for Gurdurr downloaded successfully!
# Image for Conkeldurr downloaded successfully!
# Image for Tympole downloaded successfully!
# Image for Palpitoad downloaded successfully!
# Image for Seismitoad downloaded successfully!
# Image for Throh downloaded successfully!
# Image for Sawk downloaded successfully!
# Image for Sewaddle downloaded successfully!
# Image for Swadloon downloaded successfully!
# Image for Leavanny downloaded successfully!
# Image for Venipede downloaded successfully!
# Image for Whirlipede downloaded successfully!
# Image for Scolipede downloaded successfully!
# Image for Cottonee downloaded successfully!
# Image for Whimsicott downloaded successfully!
# Image for Petilil downloaded successfully!
# Image for Lilligant downloaded successfully!
# An error occurred while processing Pokémon number 550: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Sandile downloaded successfully!
# Image for Krokorok downloaded successfully!
# Image for Krookodile downloaded successfully!
# Image for Darumaka downloaded successfully!
# An error occurred while processing Pokémon number 555: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Maractus downloaded successfully!
# Image for Dwebble downloaded successfully!
# Image for Crustle downloaded successfully!
# Image for Scraggy downloaded successfully!
# Image for Scrafty downloaded successfully!
# Image for Sigilyph downloaded successfully!
# Image for Yamask downloaded successfully!
# Image for Cofagrigus downloaded successfully!
# Image for Tirtouga downloaded successfully!
# Image for Carracosta downloaded successfully!
# Image for Archen downloaded successfully!
# Image for Archeops downloaded successfully!
# Image for Trubbish downloaded successfully!
# Image for Garbodor downloaded successfully!
# Image for Zorua downloaded successfully!
# Image for Zoroark downloaded successfully!
# Image for Minccino downloaded successfully!
# Image for Cinccino downloaded successfully!
# Image for Gothita downloaded successfully!
# Image for Gothorita downloaded successfully!
# Image for Gothitelle downloaded successfully!
# Image for Solosis downloaded successfully!
# Image for Duosion downloaded successfully!
# Image for Reuniclus downloaded successfully!
# Image for Ducklett downloaded successfully!
# Image for Swanna downloaded successfully!
# Image for Vanillite downloaded successfully!
# Image for Vanillish downloaded successfully!
# Image for Vanilluxe downloaded successfully!
# Image for Deerling downloaded successfully!
# Image for Sawsbuck downloaded successfully!
# Image for Emolga downloaded successfully!
# Image for Karrablast downloaded successfully!
# Image for Escavalier downloaded successfully!
# Image for Foongus downloaded successfully!
# Image for Amoonguss downloaded successfully!
# Image for Frillish downloaded successfully!
# Image for Jellicent downloaded successfully!
# Image for Alomomola downloaded successfully!
# Image for Joltik downloaded successfully!
# Image for Galvantula downloaded successfully!
# Image for Ferroseed downloaded successfully!
# Image for Ferrothorn downloaded successfully!
# Image for Klink downloaded successfully!
# Image for Klang downloaded successfully!
# Image for Klinklang downloaded successfully!
# Image for Tynamo downloaded successfully!
# Image for Eelektrik downloaded successfully!
# Image for Eelektross downloaded successfully!
# Image for Elgyem downloaded successfully!
# Image for Beheeyem downloaded successfully!
# Image for Litwick downloaded successfully!
# Image for Lampent downloaded successfully!
# Image for Chandelure downloaded successfully!
# Image for Axew downloaded successfully!
# Image for Fraxure downloaded successfully!
# Image for Haxorus downloaded successfully!
# Image for Cubchoo downloaded successfully!
# Image for Beartic downloaded successfully!
# Image for Cryogonal downloaded successfully!
# Image for Shelmet downloaded successfully!
# Image for Accelgor downloaded successfully!
# Image for Stunfisk downloaded successfully!
# Image for Mienfoo downloaded successfully!
# Image for Mienshao downloaded successfully!
# Image for Druddigon downloaded successfully!
# Image for Golett downloaded successfully!
# Image for Golurk downloaded successfully!
# Image for Pawniard downloaded successfully!
# Image for Bisharp downloaded successfully!
# Image for Bouffalant downloaded successfully!
# Image for Rufflet downloaded successfully!
# Image for Braviary downloaded successfully!
# Image for Vullaby downloaded successfully!
# Image for Mandibuzz downloaded successfully!
# Image for Heatmor downloaded successfully!
# Image for Durant downloaded successfully!
# Image for Deino downloaded successfully!
# Image for Zweilous downloaded successfully!
# Image for Hydreigon downloaded successfully!
# Image for Larvesta downloaded successfully!
# Image for Volcarona downloaded successfully!
# Image for Cobalion downloaded successfully!
# Image for Terrakion downloaded successfully!
# Image for Virizion downloaded successfully!
# An error occurred while processing Pokémon number 641: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 642: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Reshiram downloaded successfully!
# Image for Zekrom downloaded successfully!
# An error occurred while processing Pokémon number 645: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Kyurem downloaded successfully!
# An error occurred while processing Pokémon number 647: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 648: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Genesect downloaded successfully!
# Image for Chespin downloaded successfully!
# Image for Quilladin downloaded successfully!
# Image for Chesnaught downloaded successfully!
# Image for Fennekin downloaded successfully!
# Image for Braixen downloaded successfully!
# Image for Delphox downloaded successfully!
# Image for Froakie downloaded successfully!
# Image for Frogadier downloaded successfully!
# Image for Greninja downloaded successfully!
# Image for Bunnelby downloaded successfully!
# Image for Diggersby downloaded successfully!
# Image for Fletchling downloaded successfully!
# Image for Fletchinder downloaded successfully!
# Image for Talonflame downloaded successfully!
# Image for Scatterbug downloaded successfully!
# Image for Spewpa downloaded successfully!
# Image for Vivillon downloaded successfully!
# Image for Litleo downloaded successfully!
# Image for Pyroar downloaded successfully!
# An error occurred while processing Pokémon number 669: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Floette downloaded successfully!
# Image for Florges downloaded successfully!
# Image for Skiddo downloaded successfully!
# Image for Gogoat downloaded successfully!
# Image for Pancham downloaded successfully!
# Image for Pangoro downloaded successfully!
# Image for Furfrou downloaded successfully!
# Image for Espurr downloaded successfully!
# An error occurred while processing Pokémon number 678: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Honedge downloaded successfully!
# Image for Doublade downloaded successfully!
# An error occurred while processing Pokémon number 681: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Spritzee downloaded successfully!
# Image for Aromatisse downloaded successfully!
# Image for Swirlix downloaded successfully!
# Image for Slurpuff downloaded successfully!
# Image for Inkay downloaded successfully!
# Image for Malamar downloaded successfully!
# Image for Binacle downloaded successfully!
# Image for Barbaracle downloaded successfully!
# Image for Skrelp downloaded successfully!
# Image for Dragalge downloaded successfully!
# Image for Clauncher downloaded successfully!
# Image for Clawitzer downloaded successfully!
# Image for Helioptile downloaded successfully!
# Image for Heliolisk downloaded successfully!
# Image for Tyrunt downloaded successfully!
# Image for Tyrantrum downloaded successfully!
# Image for Amaura downloaded successfully!
# Image for Aurorus downloaded successfully!
# Image for Sylveon downloaded successfully!
# Image for Hawlucha downloaded successfully!
# Image for Dedenne downloaded successfully!
# Image for Carbink downloaded successfully!
# Image for Goomy downloaded successfully!
# Image for Sliggoo downloaded successfully!
# Image for Goodra downloaded successfully!
# Image for Klefki downloaded successfully!
# Image for Phantump downloaded successfully!
# Image for Trevenant downloaded successfully!
# An error occurred while processing Pokémon number 710: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 711: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Bergmite downloaded successfully!
# Image for Avalugg downloaded successfully!
# Image for Noibat downloaded successfully!
# Image for Noivern downloaded successfully!
# Image for Xerneas downloaded successfully!
# Image for Yveltal downloaded successfully!
# An error occurred while processing Pokémon number 718: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Diancie downloaded successfully!
# Image for Hoopa downloaded successfully!
# Image for Volcanion downloaded successfully!
# Image for Rowlet downloaded successfully!
# Image for Dartrix downloaded successfully!
# Image for Decidueye downloaded successfully!
# Image for Litten downloaded successfully!
# Image for Torracat downloaded successfully!
# Image for Incineroar downloaded successfully!
# Image for Popplio downloaded successfully!
# Image for Brionne downloaded successfully!
# Image for Primarina downloaded successfully!
# Image for Pikipek downloaded successfully!
# Image for Trumbeak downloaded successfully!
# Image for Toucannon downloaded successfully!
# Image for Yungoos downloaded successfully!
# Image for Gumshoos downloaded successfully!
# Image for Grubbin downloaded successfully!
# Image for Charjabug downloaded successfully!
# Image for Vikavolt downloaded successfully!
# Image for Crabrawler downloaded successfully!
# Image for Crabominable downloaded successfully!
# An error occurred while processing Pokémon number 741: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Cutiefly downloaded successfully!
# Image for Ribombee downloaded successfully!
# Image for Rockruff downloaded successfully!
# An error occurred while processing Pokémon number 745: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 746: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Mareanie downloaded successfully!
# Image for Toxapex downloaded successfully!
# Image for Mudbray downloaded successfully!
# Image for Mudsdale downloaded successfully!
# Image for Dewpider downloaded successfully!
# Image for Araquanid downloaded successfully!
# Image for Fomantis downloaded successfully!
# Image for Lurantis downloaded successfully!
# Image for Morelull downloaded successfully!
# Image for Shiinotic downloaded successfully!
# Image for Salandit downloaded successfully!
# Image for Salazzle downloaded successfully!
# Image for Stufful downloaded successfully!
# Image for Bewear downloaded successfully!
# Image for Bounsweet downloaded successfully!
# Image for Steenee downloaded successfully!
# Image for Tsareena downloaded successfully!
# Image for Comfey downloaded successfully!
# Image for Oranguru downloaded successfully!
# Image for Passimian downloaded successfully!
# Image for Wimpod downloaded successfully!
# Image for Golisopod downloaded successfully!
# Image for Sandygast downloaded successfully!
# Image for Palossand downloaded successfully!
# Image for Pyukumuku downloaded successfully!
# An error occurred while processing Pokémon number 772: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Silvally downloaded successfully!
# An error occurred while processing Pokémon number 774: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Komala downloaded successfully!
# Image for Turtonator downloaded successfully!
# Image for Togedemaru downloaded successfully!
# An error occurred while processing Pokémon number 778: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Bruxish downloaded successfully!
# Image for Drampa downloaded successfully!
# Image for Dhelmise downloaded successfully!
# Image for Jangmo-o downloaded successfully!
# Image for Hakamo-o downloaded successfully!
# Image for Kommo-o downloaded successfully!
# An error occurred while processing Pokémon number 785: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 786: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 787: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 788: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Cosmog downloaded successfully!
# Image for Cosmoem downloaded successfully!
# Image for Solgaleo downloaded successfully!
# Image for Lunala downloaded successfully!
# Image for Nihilego downloaded successfully!
# Image for Buzzwole downloaded successfully!
# Image for Pheromosa downloaded successfully!
# Image for Xurkitree downloaded successfully!
# Image for Celesteela downloaded successfully!
# Image for Kartana downloaded successfully!
# Image for Guzzlord downloaded successfully!
# Image for Necrozma downloaded successfully!
# Image for Magearna downloaded successfully!
# Image for Marshadow downloaded successfully!
# Image for Poipole downloaded successfully!
# Image for Naganadel downloaded successfully!
# Image for Stakataka downloaded successfully!
# Image for Blacephalon downloaded successfully!
# Image for Zeraora downloaded successfully!
# Image for Meltan downloaded successfully!
# Image for Melmetal downloaded successfully!
# Image for Grookey downloaded successfully!
# Image for Thwackey downloaded successfully!
# Image for Rillaboom downloaded successfully!
# Image for Scorbunny downloaded successfully!
# Image for Raboot downloaded successfully!
# Image for Cinderace downloaded successfully!
# Image for Sobble downloaded successfully!
# Image for Drizzile downloaded successfully!
# Image for Inteleon downloaded successfully!
# Image for Skwovet downloaded successfully!
# Image for Greedent downloaded successfully!
# Image for Rookidee downloaded successfully!
# Image for Corvisquire downloaded successfully!
# Image for Corviknight downloaded successfully!
# Image for Blipbug downloaded successfully!
# Image for Dottler downloaded successfully!
# Image for Orbeetle downloaded successfully!
# Image for Nickit downloaded successfully!
# Image for Thievul downloaded successfully!
# Image for Gossifleur downloaded successfully!
# Image for Eldegoss downloaded successfully!
# Image for Wooloo downloaded successfully!
# Image for Dubwool downloaded successfully!
# Image for Chewtle downloaded successfully!
# Image for Drednaw downloaded successfully!
# Image for Yamper downloaded successfully!
# Image for Boltund downloaded successfully!
# Image for Rolycoly downloaded successfully!
# Image for Carkol downloaded successfully!
# Image for Coalossal downloaded successfully!
# Image for Applin downloaded successfully!
# Image for Flapple downloaded successfully!
# Image for Appletun downloaded successfully!
# Image for Silicobra downloaded successfully!
# Image for Sandaconda downloaded successfully!
# Image for Cramorant downloaded successfully!
# Image for Arrokuda downloaded successfully!
# Image for Barraskewda downloaded successfully!
# Image for Toxel downloaded successfully!
# An error occurred while processing Pokémon number 849: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Sizzlipede downloaded successfully!
# Image for Centiskorch downloaded successfully!
# Image for Clobbopus downloaded successfully!
# Image for Grapploct downloaded successfully!
# Image for Sinistea downloaded successfully!
# Image for Polteageist downloaded successfully!
# Image for Hatenna downloaded successfully!
# Image for Hattrem downloaded successfully!
# Image for Hatterene downloaded successfully!
# Image for Impidimp downloaded successfully!
# Image for Morgrem downloaded successfully!
# Image for Grimmsnarl downloaded successfully!
# Image for Obstagoon downloaded successfully!
# Image for Perrserker downloaded successfully!
# Image for Cursola downloaded successfully!
# An error occurred while processing Pokémon number 865: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 866: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Runerigus downloaded successfully!
# Image for Milcery downloaded successfully!
# Image for Alcremie downloaded successfully!
# Image for Falinks downloaded successfully!
# Image for Pincurchin downloaded successfully!
# Image for Snom downloaded successfully!
# Image for Frosmoth downloaded successfully!
# Image for Stonjourner downloaded successfully!
# An error occurred while processing Pokémon number 875: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 876: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 877: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Cufant downloaded successfully!
# Image for Copperajah downloaded successfully!
# Image for Dracozolt downloaded successfully!
# Image for Arctozolt downloaded successfully!
# Image for Dracovish downloaded successfully!
# Image for Arctovish downloaded successfully!
# Image for Duraludon downloaded successfully!
# Image for Dreepy downloaded successfully!
# Image for Drakloak downloaded successfully!
# Image for Dragapult downloaded successfully!
# Image for Zacian downloaded successfully!
# Image for Zamazenta downloaded successfully!
# Image for Eternatus downloaded successfully!
# Image for Kubfu downloaded successfully!
# An error occurred while processing Pokémon number 892: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Zarude downloaded successfully!
# Image for Regieleki downloaded successfully!
# Image for Regidrago downloaded successfully!
# Image for Glastrier downloaded successfully!
# Image for Spectrier downloaded successfully!
# Image for Calyrex downloaded successfully!
# Image for Wyrdeer downloaded successfully!
# Image for Kleavor downloaded successfully!
# Image for Ursaluna downloaded successfully!
# An error occurred while processing Pokémon number 902: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Sneasler downloaded successfully!
# Image for Overqwil downloaded successfully!
# An error occurred while processing Pokémon number 905: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Sprigatito downloaded successfully!
# Image for Floragato downloaded successfully!
# Image for Meowscarada downloaded successfully!
# Image for Fuecoco downloaded successfully!
# Image for Crocalor downloaded successfully!
# Image for Skeledirge downloaded successfully!
# Image for Quaxly downloaded successfully!
# Image for Quaxwell downloaded successfully!
# Image for Quaquaval downloaded successfully!
# Image for Lechonk downloaded successfully!
# Image for Oinkologne downloaded successfully!
# Image for Tarountula downloaded successfully!
# Image for Spidops downloaded successfully!
# Image for Nymble downloaded successfully!
# Image for Lokix downloaded successfully!
# Image for Pawmi downloaded successfully!
# Image for Pawmo downloaded successfully!
# Image for Pawmot downloaded successfully!
# Image for Tandemaus downloaded successfully!
# Image for Maushold downloaded successfully!
# Image for Fidough downloaded successfully!
# Image for Dachsbun downloaded successfully!
# Image for Smoliv downloaded successfully!
# Image for Dolliv downloaded successfully!
# Image for Arboliva downloaded successfully!
# Image for Squawkabilly downloaded successfully!
# Image for Nacli downloaded successfully!
# Image for Naclstack downloaded successfully!
# Image for Garganacl downloaded successfully!
# Image for Charcadet downloaded successfully!
# Image for Armarouge downloaded successfully!
# Image for Ceruledge downloaded successfully!
# Image for Tadbulb downloaded successfully!
# Image for Bellibolt downloaded successfully!
# Image for Wattrel downloaded successfully!
# Image for Kilowattrel downloaded successfully!
# Image for Maschiff downloaded successfully!
# Image for Mabosstiff downloaded successfully!
# Image for Shroodle downloaded successfully!
# Image for Grafaiai downloaded successfully!
# Image for Bramblin downloaded successfully!
# Image for Brambleghast downloaded successfully!
# Image for Toedscool downloaded successfully!
# Image for Toedscruel downloaded successfully!
# Image for Klawf downloaded successfully!
# Image for Capsakid downloaded successfully!
# Image for Scovillain downloaded successfully!
# Image for Rellor downloaded successfully!
# Image for Rabsca downloaded successfully!
# Image for Flittle downloaded successfully!
# Image for Espathra downloaded successfully!
# Image for Tinkatink downloaded successfully!
# Image for Tinkatuff downloaded successfully!
# Image for Tinkaton downloaded successfully!
# Image for Wiglett downloaded successfully!
# Image for Wugtrio downloaded successfully!
# Image for Bombirdier downloaded successfully!
# Image for Finizen downloaded successfully!
# Image for Palafin downloaded successfully!
# Image for Varoom downloaded successfully!
# Image for Revavroom downloaded successfully!
# Image for Cyclizar downloaded successfully!
# Image for Orthworm downloaded successfully!
# Image for Glimmet downloaded successfully!
# Image for Glimmora downloaded successfully!
# Image for Greavard downloaded successfully!
# Image for Houndstone downloaded successfully!
# Image for Flamigo downloaded successfully!
# Image for Cetoddle downloaded successfully!
# Image for Cetitan downloaded successfully!
# Image for Veluza downloaded successfully!
# Image for Dondozo downloaded successfully!
# Image for Tatsugiri downloaded successfully!
# Image for Annihilape downloaded successfully!
# Image for Clodsire downloaded successfully!
# Image for Farigiraf downloaded successfully!
# Image for Dudunsparce downloaded successfully!
# Image for Kingambit downloaded successfully!
# An error occurred while processing Pokémon number 984: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 985: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 986: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 987: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 988: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 989: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 990: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 991: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 992: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 993: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 994: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 995: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Frigibax downloaded successfully!
# Image for Arctibax downloaded successfully!
# Image for Baxcalibur downloaded successfully!
# Image for Gimmighoul downloaded successfully!
# Image for Gholdengo downloaded successfully!
# An error occurred while processing Pokémon number 1001: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 1002: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 1003: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 1004: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 1005: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 1006: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Koraidon downloaded successfully!
# Image for Miraidon downloaded successfully!
# An error occurred while processing Pokémon number 1009: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# An error occurred while processing Pokémon number 1010: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Dipplin downloaded successfully!
# Image for Poltchageist downloaded successfully!
# An error occurred while processing Pokémon number 1013: Invalid URL 'None': No scheme supplied. Perhaps you meant https://None?
# Image for Okidogi downloaded successfully!
# Image for Munkidori downloaded successfully!
# Image for Fezandipiti downloaded successfully!
# Image for Ogerpon downloaded successfully!

# %%
t = pypokedex.get(dex=1017)

t.name
# Out:
# 'ogerpon'

# %%
import json
import os
import pypokedex

pokemon_data = []

for dex in range(1, 1018):
    try:
        # get pokemon
        p = pypokedex.get(dex=dex)
        
        # print status
        print(f"{p.name.capitalize()}")

        # get moves
        first_key = list(p.moves.keys())[0]
        move_data = p.moves[first_key]
        moves = [move.name for move in move_data]

        base_stats = {
            'hp': p.base_stats.hp,
            'attack': p.base_stats.attack,
            'defense': p.base_stats.defense,
            'sp_atk': p.base_stats.sp_atk,
            'sp_def': p.base_stats.sp_def,
            'speed': p.base_stats.speed
        }
        data = {
            'name': p.name.capitalize(),
            'health': p.base_stats.hp,  # Assume a default health of 100
            'types': p.types,
            'image_path': f'img\\{p.name.capitalize()}.png',
            'moves': moves,  # Could truncate this to limit moves?
            'base_stats': base_stats
        }
        pokemon_data.append(data)
    except Exception as e:
        print(f"An error occurred while processing Pokémon number {dex}: {e}")

# Check if file already exists to prevent accidental overwriting
filename = 'pokemon_data.json'
if os.path.exists(filename):
    overwrite = input(f"{filename} already exists. Do you want to overwrite it? (y/n): ")
    if overwrite.lower() != 'y':
        print("Operation cancelled.")
        exit()

# Write to pokemon_data.json
with open(filename, 'w') as file:
    json.dump(pokemon_data, file, indent=4)
# Out:
# Bulbasaur
# Ivysaur
# Quaquaval
# Lechonk
# Oinkologne
# Tarountula
# Spidops
# Nymble
# Lokix
# Pawmi
# Pawmo
# Pawmot
# Tandemaus
# Maushold
# Fidough
# Dachsbun
# Smoliv
# Dolliv
# Arboliva
# Squawkabilly
# Nacli
# Naclstack
# Garganacl
# Charcadet
# Armarouge
# Ceruledge
# Tadbulb
# Bellibolt
# Wattrel
# Kilowattrel
# Maschiff
# Mabosstiff
# Shroodle
# Grafaiai
# Bramblin
# Brambleghast
# Toedscool
# Toedscruel
# Klawf
# Capsakid
# Scovillain
# Rellor
# Rabsca
# Flittle
# Espathra
# Tinkatink
# Tinkatuff
# Tinkaton
# Wiglett
# Wugtrio
# Bombirdier
# Finizen
# Palafin
# Varoom
# Revavroom
# Cyclizar
# Orthworm
# Glimmet
# Glimmora
# Greavard
# Houndstone
# Flamigo
# Cetoddle
# Cetitan
# Veluza
# Dondozo
# Tatsugiri
# Annihilape
# Clodsire
# Farigiraf
# Dudunsparce
# Kingambit
# Great-tusk
# Scream-tail
# Brute-bonnet
# Flutter-mane
# Slither-wing
# Sandy-shocks
# Iron-treads
# Iron-bundle
# Iron-hands
# Iron-jugulis
# Iron-moth
# Iron-thorns
# Frigibax
# Arctibax
# Baxcalibur
# Gimmighoul
# Gholdengo
# Wo-chien
# Chien-pao
# Ting-lu
# Chi-yu
# Roaring-moon
# Iron-valiant
# Koraidon
# Miraidon
# Walking-wake
# Iron-leaves
# Dipplin
# Poltchageist
# Sinistcha
# Okidogi
# Munkidori
# Fezandipiti
# Ogerpon

# %%
p5.types
# Out:
# ['fire']

# %% [markdown]
# # Find pokemon moves

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = 'https://bulbapedia.bulbagarden.net/wiki/List_of_moves'

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

#tables = pd.read_html(url)

# Now `tables` is a list of dataframes, each one representing a table from the webpage
# You can access individual tables like this:
#move_table = tables[0]

# %%
table_html = soup.find('table')

# %%
df = pd.read_html(str(table_html))[0]

df = df.drop(0).reset_index(drop=True)

df.columns = df.iloc[0]

df = df.drop(0).reset_index(drop=True)

df
# Out:
# C:\Users\ytsop\AppData\Local\Temp\ipykernel_10788\3650037193.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table_html))[0]
# 0      #            Name      Type  Category   PP Power Accuracy Gen
# 0      1           Pound    Normal  Physical   35    40     100%   I
# 1      2     Karate Chop  Fighting  Physical   25    50     100%   I
# 2      3     Double Slap    Normal  Physical   10    15      85%   I
# 3      4     Comet Punch    Normal  Physical   15    18      85%   I
# 4      5      Mega Punch    Normal  Physical   20    80      85%   I
# ..   ...             ...       ...       ...  ...   ...      ...  ..
# 904  ???    Electro Shot  Electric   Special  NaN   NaN      NaN  IX
# 905  ???     Thunderclap  Electric   Special  NaN   NaN      NaN  IX
# 906  ???  Tachyon Cutter     Steel   Special  NaN   NaN      NaN  IX
# 907  ???      Upper Hand  Fighting  Physical  NaN   NaN      NaN  IX
# 908  ???   Psychic Noise   Psychic   Special  NaN   NaN      NaN  IX
#
# [909 rows x 8 columns]

# %%
# Define a function to check if a value can be converted to an integer
def is_integer(value):
    try:
        int(value)
        return True
    except (ValueError, TypeError):
        return False

# Filter the DataFrame to keep only rows where 'Power' can be converted to an integer
df = df[df['Power'].apply(is_integer)]

# Convert the 'Power' column to integers, scale to fit with the HP
df['Power'] = df['Power'].astype(int) * .2

# Convert 'Name' of moves to match version in pokedex
# Converting the 'name' column to lowercase and replacing spaces with hyphens
df['Name'] = df['Name'].str.lower().str.replace(' ', '-')


df.head(20)
# Out:
# C:\Users\ytsop\AppData\Local\Temp\ipykernel_10788\2760911222.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Power'] = df['Power'].astype(int) * .2
# C:\Users\ytsop\AppData\Local\Temp\ipykernel_10788\2760911222.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'] = df['Name'].str.lower().str.replace(' ', '-')
# 0    #           Name      Type  Category  PP  Power Accuracy Gen
# 0    1          pound    Normal  Physical  35    8.0     100%   I
# 1    2    karate-chop  Fighting  Physical  25   10.0     100%   I
# 2    3    double-slap    Normal  Physical  10    3.0      85%   I
# 3    4    comet-punch    Normal  Physical  15    3.6      85%   I
# 4    5     mega-punch    Normal  Physical  20   16.0      85%   I
# 5    6        pay-day    Normal  Physical  20    8.0     100%   I
# 6    7     fire-punch      Fire  Physical  15   15.0     100%   I
# 7    8      ice-punch       Ice  Physical  15   15.0     100%   I
# 8    9  thunder-punch  Electric  Physical  15   15.0     100%   I
# 9   10        scratch    Normal  Physical  35    8.0     100%   I
# 10  11      vise-grip    Normal  Physical  30   11.0     100%   I
# 12  13     razor-wind    Normal   Special  10   16.0     100%   I
# 14  15            cut    Normal  Physical  30   10.0      95%   I
# 15  16           gust    Flying   Special  35    8.0     100%   I
# 16  17    wing-attack    Flying  Physical  35   12.0     100%   I
# 18  19            fly    Flying  Physical  15   18.0      95%   I
# 19  20           bind    Normal  Physical  20    3.0      85%   I
# 20  21           slam    Normal  Physical  20   16.0      75%   I
# 21  22      vine-whip     Grass  Physical  25    9.0     100%   I
# 22  23          stomp    Normal  Physical  20   13.0     100%   I

# %%
# Type advantage dictionary

type_advantages = {
    "Normal": {
        "strength_against": [],
        "weakness_against": ["Rock", "Steel"]
    },
    "Fire": {
        "strength_against": ["Grass", "Ice", "Bug", "Steel"],
        "weakness_against": ["Fire", "Water", "Rock", "Dragon"]
    },
    "Water": {
        "strength_against": ["Fire", "Ground", "Rock"],
        "weakness_against": ["Water", "Electric", "Grass", "Dragon"]
    },
    "Electric": {
        "strength_against": ["Water", "Flying"],
        "weakness_against": ["Electric", "Ground", "Grass", "Dragon"]
    },
    "Grass": {
        "strength_against": ["Water", "Ground", "Rock"],
        "weakness_against": ["Fire", "Grass", "Poison", "Flying", "Bug", "Dragon", "Steel"]
    },
    "Ice": {
        "strength_against": ["Grass", "Ground", "Flying", "Dragon"],
        "weakness_against": ["Fire", "Water", "Ice", "Steel"]
    },
    "Fighting": {
        "strength_against": ["Normal", "Ice", "Rock", "Dark", "Steel"],
        "weakness_against": ["Poison", "Flying", "Psychic", "Bug", "Fairy"]
    },
    "Poison": {
        "strength_against": ["Grass", "Fairy"],
        "weakness_against": ["Poison", "Ground", "Rock", "Ghost"]
    },
    "Ground": {
        "strength_against": ["Fire", "Electric", "Poison", "Rock", "Steel"],
        "weakness_against": ["Grass", "Ice", "Water", "Bug"]
    },
    "Flying": {
        "strength_against": ["Grass", "Fighting", "Bug"],
        "weakness_against": ["Electric", "Rock", "Steel"]
    },
    "Psychic": {
        "strength_against": ["Fighting", "Poison"],
        "weakness_against": ["Psychic", "Steel"]
    },
    "Bug": {
        "strength_against": ["Grass", "Psychic", "Dark"],
        "weakness_against": ["Fire", "Fighting", "Poison", "Flying", "Ghost", "Steel", "Fairy"]
    },
    "Rock": {
        "strength_against": ["Fire", "Ice", "Flying", "Bug"],
        "weakness_against": ["Fighting", "Ground", "Steel"]
    },
    "Ghost": {
        "strength_against": ["Psychic", "Ghost"],
        "weakness_against": ["Dark"]
    },
    "Dragon": {
        "strength_against": ["Dragon"],
        "weakness_against": ["Steel"]
    },
    "Dark": {
        "strength_against": ["Psychic", "Ghost"],
        "weakness_against": ["Fighting", "Dark", "Fairy"]
    },
    "Steel": {
        "strength_against": ["Ice", "Rock", "Fairy"],
        "weakness_against": ["Fire", "Water", "Electric", "Steel"]
    },
    "Fairy": {
        "strength_against": ["Fighting", "Dragon", "Dark"],
        "weakness_against": ["Fire", "Poison", "Steel"]
    }
}

# %%
import json


# list to hold the data
data = []

# iterate over the rows of the DataFrame
for index, row in df.iterrows():
    name = row[1].lower()  # assuming the name is in the second column
    power = row[5]  # assuming the power is in the sixth column
    type_ = row[2]  # assuming the type is in the third column
    
    # get the strengths and weaknesses from the mapping
    strength_against = type_advantages.get(type_, {}).get("strength_against", None)
    weakness_against = type_advantages.get(type_, {}).get("weakness_against", None)
    
    # create a dictionary for this row
    move_data = {
        "name": name,
        "power": power,
        "strength_against": strength_against,
        "weakness_against": weakness_against
    }
    
    # append the dictionary to the list
    data.append(move_data)

# convert the list to JSON
json_data = json.dumps(data, indent=4)

# write the JSON data to a file
with open('moves_data.json', 'w') as f:
    f.write(json_data)
# Out:
# C:\Users\ytsop\AppData\Local\Temp\ipykernel_10788\3033047564.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   name = row[1].lower()  # assuming the name is in the second column
# C:\Users\ytsop\AppData\Local\Temp\ipykernel_10788\3033047564.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   power = row[5]  # assuming the power is in the sixth column
# C:\Users\ytsop\AppData\Local\Temp\ipykernel_10788\3033047564.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   type_ = row[2]  # assuming the type is in the third column

# %%
df.sort_values(by="Power", ascending=False)
# Out:
# 0      #                         Name      Type  Category  PP  Power Accuracy  \
# 152  153                    Explosion    Normal  Physical   5   50.0     100%
# 700  701          Pulverizing Pancake    Normal  Physical   1   42.0       —%
# 657  658                 Catastropika  Electric  Physical   1   42.0       —%
# 119  120                Self-Destruct    Normal  Physical   5   40.0     100%
# 724  725  Menacing Moonraze Maelstrom     Ghost   Special   1   40.0       —%
# ..   ...                          ...       ...       ...  ..    ...      ...
# 34    35                         Wrap    Normal  Physical  20    3.0      90%
# 39    40                 Poison Sting    Poison  Physical  35    3.0     100%
# 30    31                  Fury Attack    Normal  Physical  20    3.0      85%
# 131  132                    Constrict    Normal  Physical  35    2.0     100%
# 166  167                  Triple Kick  Fighting  Physical  10    2.0      90%
#
# 0    Gen
# 152    I
# 700  VII
# 657  VII
# 119    I
# 724  VII
# ..   ...
# 34     I
# 39     I
# 30     I
# 131    I
# 166   II
#
# [539 rows x 8 columns]
